# %% [markdown]
# # Triton Meets ArangoDB: Amazon Product Recommendation Application using GraphSage Algorithm

# %% [markdown]
# In this notebook, we will build an Amazon Product Recommendation application by leveraging three technologies at a time i.e. Graph Machine Learning, Nvidia's Triton inference server and ArangoDB.

# %%
import warnings
warnings.filterwarnings('ignore')
import torch
import torch.nn.functional as F
from tqdm import tqdm
from torch_geometric.data import NeighborSampler
from torch_geometric.nn import SAGEConv
import os.path as osp
import pandas as pd
import numpy as np
import collections
from pandas.core.common import flatten
# importing obg datatset
from ogb.nodeproppred import PygNodePropPredDataset, Evaluator
from pandas.core.common import flatten
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(14.7,4.27)})
sns.set_theme(style="ticks")
import collections
from scipy.special import softmax
import umap
from arango import ArangoClient
import oasis
import pprint
import tritongrpcclient
import tritongrpcclient.model_config_pb2 as mc
import tritonhttpclient
from tritonclientutils import triton_to_np_dtype
from tritonclientutils import InferenceServerException
from scipy.special import softmax
import mplcursors
# Out:
# /home/sachin/anaconda3/envs/pyg/lib/python3.8/site-packages/tritongrpcclient/__init__.py:31: DeprecationWarning: The package `tritongrpcclient` is deprecated and will be removed in a future version. Please use instead `tritonclient.grpc`
#   warnings.warn(
# /home/sachin/anaconda3/envs/pyg/lib/python3.8/site-packages/tritongrpcclient/model_config_pb2.py:31: DeprecationWarning: The package `tritongrpcclient` is deprecated and will be removed in a future version. Please use instead `tritonclient.grpc.model_config_pb2`
#   warnings.warn(
# /home/sachin/anaconda3/envs/pyg/lib/python3.8/site-packages/tritonhttpclient/__init__.py:31: DeprecationWarning: The package `tritonhttpclient` is deprecated and will be removed in a future version. Please use instead `tritonclient.http`
#   warnings.warn(
# /home/sachin/anaconda3/envs/pyg/lib/python3.8/site-packages/tritonclientutils/__init__.py:31: DeprecationWarning: The package `tritonclientutils` is deprecated and will be removed in a future version. Please use instead `tritonclient.utils`
#   warnings.warn(

# %%
root = "/home/sachin/Desktop/arangoml/datasets"

# %%
dataset = PygNodePropPredDataset('ogbn-products', root)

# %%
# getting train val test split idx based on sales ranking
split_idx = dataset.get_idx_split()
evaluator = Evaluator(name='ogbn-products')
data = dataset[0]

# %%
# storing train, validation and test node indices
train_idx = split_idx['train']
valid_idx = split_idx['valid']
test_idx = split_idx['test']

# %%
# test node indexes
test_idx
# Out:
# tensor([ 235938,  235939,  235940,  ..., 2449026, 2449027, 2449028])

# %%
# neighborhood sampling of test nodes
test_loader = NeighborSampler(data.edge_index, node_idx=test_idx,
                              sizes=[15, 10, 5], batch_size=1,
                              shuffle=False, num_workers=12)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# node feature matrix
x = data.x.to(device)

# %%
# labels
y = data.y.to(device)

# %%
# creating adjs for performing a trace on the GraphSage model
# will contain only edge_idx and size attributes

max_nodes = 1000
def create_triton_input(dummy_n_ids, dummy_adjs):
    edge_list_0 = []
    edge_list_1 = []
    edge_list_2 = []
    edge_adjs = []
    for idx, e_idx in enumerate(dummy_adjs[0]):
        if idx == 0:
            edge_list_0.append(e_idx[0])
            #edge_list_0.append(e_idx[1])
            edge_list_0.append(torch.tensor(np.asarray(e_idx[2])))
        elif idx == 1:
            edge_list_1.append(e_idx[0])
            #edge_list_1.append(e_idx[1])
            edge_list_1.append(torch.tensor(np.asarray(e_idx[2])))
        else:
            edge_list_2.append(e_idx[0])
            #edge_list_2.append(e_idx[1])
            edge_list_2.append(torch.tensor(np.asarray(e_idx[2])))
    
    # creating edge indexes
    edge_index_0 = edge_list_0[0]
    edge_index_0 = edge_index_0.to(device)
    edge_size_0 = edge_list_0[1]
    edge_size_0 = edge_size_0.to(device)

    edge_index_1 = edge_list_1[0]
    edge_index_1 = edge_index_1.to(device)
    edge_size_1 = edge_list_1[1]
    edge_size_1 = edge_size_1.to(device)

    edge_index_2 = edge_list_2[0]
    edge_index_2 = edge_index_2.to(device)
    edge_size_2 = edge_list_2[1]
    edge_size_2 = edge_size_2.to(device)
    
    
    # add padding to node feature matrix
    dummy_x = x[dummy_n_ids[0]]
    total_nodes = dummy_x.size(0)
    nodes_padded = max_nodes - total_nodes
    dummy_x_pad = F.pad(input=dummy_x, pad=(0, 0, 0, nodes_padded), mode='constant', value=0)
    dummy_x_pad = dummy_x_pad.to(device)
    
    return dummy_x_pad, edge_index_0, edge_size_0, edge_index_1, edge_size_1, edge_index_2, edge_size_2

# %%
# setting inputs and output names as same in config file
input_name = ['input__0', 'input__1', 'input__2', 'input__3', 'input__4', 'input__5', 'input__6']
output_name = ['output__0', 'output__1', 'output__2']
VERBOSE = False
from tritonclient.utils import *

# %% [markdown]
# ## Client-Side Script to Interact with Triton Inference Server

# %% [markdown]
# The run_inference function computes the node embeddings of a given node at three different layers of trained GraphSage model and returns the same. This function requires 7 inputs:
#
# { node_matrix: Padded node feature matrix consiting of nodes involved in the computation      graph
#
#   edge_index_0: adjacency list for all the edges involved at the Hop-3 (layer-3)
#
#   edge_size_0 : shape of the bipartite graph at Hop-3
#
#   edge_index_1: adjacency list for all the edges involved at the Hop-2 (layer-2)
#
#   edge_size_1 : shape of the bipartite graph at Hop-2
#
#   edge_index_2: adjacency list for all the edges involved at the Hop-1 (layer-1)
#
#   edge_size_2 : shape of the bipartite graph at Hop-1
# }
#
# Note: Neighborhood sampler returns ajacency list in reversed order

# %%
def run_inference(node_matrix, edge_index_0, edge_size_0, edge_index_1, edge_size_1, edge_index_2, edge_size_2, model_name='graph_embeddings', url='127.0.0.1:8000', model_version='1'):
    triton_client = tritonhttpclient.InferenceServerClient(
        url=url, verbose=VERBOSE)
    model_metadata = triton_client.get_model_metadata(
        model_name=model_name, model_version=model_version)
    model_config = triton_client.get_model_config(
        model_name=model_name, model_version=model_version)
    # I have restricted the input sequence length to 256

    input_node_matrix = node_matrix
    input_node_matrix  = np.array(input_node_matrix.cpu(), dtype=np.float32)
    
    # edges_indexes and sizes
    ed_index_0 = np.array(edge_index_0.cpu(), dtype=np.int64)
    ed_index_1 = np.array(edge_index_1.cpu(), dtype=np.int64)
    ed_index_2 = np.array(edge_index_2.cpu(), dtype=np.int64)
    
    ed_size_0 = np.array(edge_size_0.cpu(), dtype=np.int64)
    ed_size_1 = np.array(edge_size_1.cpu(), dtype=np.int64)
    ed_size_2 = np.array(edge_size_2.cpu(), dtype=np.int64)
    


    input0 = tritonhttpclient.InferInput(input_name[0], (1000,  100), 'FP32')
    input0.set_data_from_numpy(input_node_matrix, binary_data=False)
    
    #layer-1
    input1 = tritonhttpclient.InferInput(input_name[1], ed_index_0.shape, 'INT64')
    input1.set_data_from_numpy(ed_index_0, binary_data=False)
    #size
    input2 = tritonhttpclient.InferInput(input_name[2], (2,), 'INT64')
    input2.set_data_from_numpy(ed_size_0, binary_data=False)
    
    #layer-2
    input3 = tritonhttpclient.InferInput(input_name[3], ed_index_1.shape, 'INT64')
    input3.set_data_from_numpy(ed_index_1, binary_data=False)
    #size
    input4 = tritonhttpclient.InferInput(input_name[4], (2,), 'INT64')
    input4.set_data_from_numpy(ed_size_1, binary_data=False)
    
    #layer-3
    input5 = tritonhttpclient.InferInput(input_name[5], ed_index_2.shape, 'INT64')
    input5.set_data_from_numpy(ed_index_2, binary_data=False)
    #size
    input6 = tritonhttpclient.InferInput(input_name[6], (2,), 'INT64')
    input6.set_data_from_numpy(ed_size_2, binary_data=False)
    
    output0 = tritonhttpclient.InferRequestedOutput(output_name[0],  binary_data=False)
    output1 = tritonhttpclient.InferRequestedOutput(output_name[1],  binary_data=False)
    output2 = tritonhttpclient.InferRequestedOutput(output_name[2],  binary_data=False)
    
    response = triton_client.infer(model_name, model_version=model_version, inputs=[input0, input1, input2, input3, input4, input5, input6], outputs=[output0, output1, output2])
    # layer-1 embeddings
    embeddings_layer_1 = response.as_numpy('output__0')
    # layer-2 embeddings
    embeddings_layer_2 = response.as_numpy('output__1')
    # # layer-3 embeddings
    embeddings_layer_3 = response.as_numpy('output__2')
    return embeddings_layer_1, embeddings_layer_2, embeddings_layer_3

# %%
# load integer to real product category label mapping
df = pd.read_csv('/home/sachin/Desktop/arangoml/datasets/ogbn_products/mapping/labelidx2productcategory.csv.gz')

# %%
label_idx, prod_cat = df.iloc[: ,0].values, df.iloc[: ,1].values
label_mapping = dict(zip(label_idx, prod_cat))

# %% [markdown]
# For the demonstration purpose we will use first 5000 test nodes for the Inference

# %%
# selecting test nodes and its adjacency matrix

layer_3_embs = []
layer_2_embs = []
for idx, (batch_size, n_id, adjs) in enumerate(test_loader):
        print("idx:", idx)
        dummy_n_ids = []
        dummy_adjs = []
        dummy_n_ids.append(n_id)
        dummy_adjs.append(adjs)
        
        if len(dummy_n_ids[0]) == 1:
            print("Found Disconnected Node in the graph at index:", idx)
            layer_3_embs.append("Disconnected Node")
        elif idx == 5000:
            break
        else:
            # creating triton input
            dummy_x_pad, edge_index_0, edge_size_0, edge_index_1, edge_size_1, edge_index_2, edge_size_2 = create_triton_input(dummy_n_ids, dummy_adjs)
            # generating node embeddings for test node from Triton Server
            emb1, emb2, emb3 = run_inference(dummy_x_pad, edge_index_0, edge_size_0, edge_index_1, edge_size_1, edge_index_2, edge_size_2)
            layer_3_embs.append(emb3[0])
# Out:
# idx: 0
# idx: 1
# idx: 2
# idx: 3
# idx: 4
# idx: 5
# idx: 6
# idx: 7
# idx: 8
# idx: 9
# idx: 10
# idx: 11
# idx: 12
# idx: 13
# idx: 14
# idx: 15
# idx: 16
# idx: 17
# idx: 18
# idx: 19
# idx: 20
# idx: 21
# idx: 22
# idx: 23
# idx: 24
# idx: 25
# idx: 26
# idx: 27
# idx: 28
# idx: 29
# idx: 30
# idx: 31
# idx: 32
# idx: 33
# idx: 34
# idx: 35
# Found Disconnected Node in the graph at index: 35
# idx: 36
# idx: 37
# idx: 38
# idx: 39
# idx: 40
# idx: 41
# idx: 42
# idx: 43
# idx: 44
# idx: 45
# idx: 46
# idx: 47
# idx: 48
# idx: 49
# idx: 50
# idx: 51
# idx: 52
# idx: 53
# idx: 54
# idx: 55
# idx: 56
# idx: 57
# idx: 58
# idx: 59
# idx: 60
# idx: 61
# idx: 62
# idx: 63
# idx: 64
# idx: 65
# idx: 66
# idx: 67
# idx: 68
# idx: 69
# idx: 70
# idx: 71
# idx: 72
# idx: 73
# idx: 74
# idx: 75
# idx: 76
# idx: 77
# idx: 78
# idx: 79
# idx: 80
# idx: 81
# idx: 82
# idx: 83
# idx: 84
# idx: 85
# idx: 86
# idx: 87
# idx: 88
# idx: 89
# idx: 90
# idx: 91
# idx: 92
# idx: 93
# idx: 94
# idx: 95
# idx: 96
# idx: 97
# idx: 98
# idx: 99
# idx: 100
# idx: 101
# idx: 102
# idx: 103
# idx: 104
# idx: 105
# idx: 106
# idx: 107
# idx: 108
# idx: 109
# idx: 110
# idx: 111
# idx: 112
# idx: 113
# idx: 114
# idx: 115
# idx: 116
# idx: 117
# idx: 118
# idx: 119
# idx: 120
# idx: 121
# idx: 122
# idx: 123
# idx: 124
# idx: 125
# idx: 126
# idx: 127
# idx: 128
# idx: 129
# idx: 130
# idx: 131
# idx: 132
# idx: 133
# idx: 134
# idx: 135
# idx: 136
# idx: 137
# idx: 138
# idx: 139
# idx: 140
# idx: 141
# idx: 142
# idx: 143
# idx: 144
# idx: 145
# Found Disconnected Node in the graph at index: 145
# idx: 146
# idx: 147
# idx: 148
# idx: 149
# idx: 150
# idx: 151
# idx: 152
# idx: 153
# idx: 154
# idx: 155
# idx: 156
# idx: 157
# idx: 158
# idx: 159
# idx: 160
# idx: 161
# idx: 162
# idx: 163
# idx: 164
# idx: 165
# idx: 166
# idx: 167
# idx: 168
# idx: 169
# idx: 170
# idx: 171
# idx: 172
# idx: 173
# idx: 174
# idx: 175
# idx: 176
# idx: 177
# idx: 178
# idx: 179
# idx: 180
# idx: 181
# idx: 182
# idx: 183
# idx: 184
# idx: 185
# idx: 186
# idx: 187
# idx: 188
# idx: 189
# idx: 190
# idx: 191
# idx: 192
# idx: 193
# idx: 194
# idx: 195
# idx: 196
# idx: 197
# idx: 198
# idx: 199
# idx: 200
# idx: 201
# idx: 202
# idx: 203
# idx: 204
# idx: 205
# idx: 206
# idx: 207
# idx: 208
# idx: 209
# idx: 210
# idx: 211
# idx: 212
# idx: 213
# idx: 214
# idx: 215
# idx: 216
# idx: 217
# idx: 218
# idx: 219
# idx: 220
# idx: 221
# idx: 222
# idx: 223
# idx: 224
# idx: 225
# idx: 226
# idx: 227
# idx: 228
# idx: 229
# idx: 230
# idx: 231
# idx: 232
# idx: 233
# idx: 234
# idx: 235
# idx: 236
# idx: 237
# idx: 238
# idx: 239
# idx: 240
# idx: 241
# idx: 242
# idx: 243
# idx: 244
# idx: 245
# idx: 246
# idx: 247
# idx: 248
# Found Disconnected Node in the graph at index: 248
# idx: 249
# idx: 250
# idx: 251
# idx: 252
# idx: 253
# idx: 254
# idx: 255
# idx: 256
# idx: 257
# idx: 258
# idx: 259
# Found Disconnected Node in the graph at index: 259
# idx: 260
# idx: 261
# idx: 262
# idx: 263
# idx: 264
# idx: 265
# idx: 266
# idx: 267
# idx: 268
# idx: 269
# idx: 270
# idx: 271
# idx: 272
# Found Disconnected Node in the graph at index: 272
# idx: 273
# idx: 274
# idx: 275
# idx: 276
# idx: 277
# idx: 278
# idx: 279
# idx: 280
# idx: 281
# idx: 282
# idx: 283
# idx: 284
# idx: 285
# Found Disconnected Node in the graph at index: 285
# idx: 286
# idx: 287
# idx: 288
# idx: 289
# idx: 290
# idx: 291
# idx: 292
# idx: 293
# idx: 294
# idx: 295
# idx: 296
# idx: 297
# idx: 298
# idx: 299
# idx: 300
# idx: 301
# idx: 302
# idx: 303
# idx: 304
# idx: 305
# idx: 306
# idx: 307
# idx: 308
# idx: 309
# idx: 310
# idx: 311
# idx: 312
# idx: 313
# idx: 314
# idx: 315
# idx: 316
# idx: 317
# idx: 318
# idx: 319
# idx: 320
# idx: 321
# idx: 322
# idx: 323
# idx: 324
# idx: 325
# idx: 326
# idx: 327
# idx: 328
# idx: 329
# idx: 330
# idx: 331
# Found Disconnected Node in the graph at index: 331
# idx: 332
# idx: 333
# idx: 334
# idx: 335
# idx: 336
# idx: 337
# idx: 338
# idx: 339
# idx: 340
# idx: 341
# idx: 342
# idx: 343
# idx: 344
# idx: 345
# idx: 346
# idx: 347
# idx: 348
# idx: 349
# idx: 350
# idx: 351
# idx: 352
# Found Disconnected Node in the graph at index: 352
# idx: 353
# idx: 354
# idx: 355
# idx: 356
# idx: 357
# idx: 358
# idx: 359
# idx: 360
# idx: 361
# idx: 362
# idx: 363
# idx: 364
# idx: 365
# idx: 366
# idx: 367
# idx: 368
# idx: 369
# idx: 370
# idx: 371
# idx: 372
# idx: 373
# Found Disconnected Node in the graph at index: 373
# idx: 374
# idx: 375
# idx: 376
# idx: 377
# idx: 378
# idx: 379
# idx: 380
# idx: 381
# idx: 382
# idx: 383
# idx: 384
# idx: 385
# idx: 386
# idx: 387
# idx: 388
# idx: 389
# idx: 390
# idx: 391
# idx: 392
# idx: 393
# idx: 394
# idx: 395
# idx: 396
# idx: 397
# idx: 398
# idx: 399
# idx: 400
# idx: 401
# idx: 402
# idx: 403
# idx: 404
# idx: 405
# idx: 406
# idx: 407
# idx: 408
# idx: 409
# idx: 410
# idx: 411
# idx: 412
# idx: 413
# idx: 414
# idx: 415
# idx: 416
# idx: 417
# idx: 418
# idx: 419
# idx: 420
# idx: 421
# idx: 422
# idx: 423
# idx: 424
# idx: 425
# idx: 426
# idx: 427
# idx: 428
# idx: 429
# idx: 430
# Found Disconnected Node in the graph at index: 430
# idx: 431
# idx: 432
# Found Disconnected Node in the graph at index: 432
# idx: 433
# idx: 434
# idx: 435
# Found Disconnected Node in the graph at index: 435
# idx: 436
# idx: 437
# idx: 438
# idx: 439
# idx: 440
# idx: 441
# idx: 442
# idx: 443
# idx: 444
# idx: 445
# idx: 446
# idx: 447
# idx: 448
# idx: 449
# idx: 450
# idx: 451
# idx: 452
# idx: 453
# idx: 454
# idx: 455
# idx: 456
# idx: 457
# idx: 458
# idx: 459
# idx: 460
# idx: 461
# idx: 462
# idx: 463
# idx: 464
# idx: 465
# idx: 466
# idx: 467
# idx: 468
# idx: 469
# idx: 470
# idx: 471
# idx: 472
# idx: 473
# idx: 474
# idx: 475
# Found Disconnected Node in the graph at index: 475
# idx: 476
# idx: 477
# idx: 478
# idx: 479
# idx: 480
# idx: 481
# Found Disconnected Node in the graph at index: 481
# idx: 482
# idx: 483
# idx: 484
# idx: 485
# idx: 486
# idx: 487
# idx: 488
# idx: 489
# idx: 490
# idx: 491
# idx: 492
# idx: 493
# idx: 494
# idx: 495
# idx: 496
# idx: 497
# idx: 498
# idx: 499
# idx: 500
# idx: 501
# idx: 502
# idx: 503
# idx: 504
# idx: 505
# idx: 506
# idx: 507
# idx: 508
# idx: 509
# idx: 510
# idx: 511
# idx: 512
# idx: 513
# idx: 514
# idx: 515
# idx: 516
# idx: 517
# idx: 518
# idx: 519
# idx: 520
# idx: 521
# idx: 522
# idx: 523
# idx: 524
# idx: 525
# idx: 526
# idx: 527
# idx: 528
# idx: 529
# idx: 530
# idx: 531
# idx: 532
# idx: 533
# idx: 534
# idx: 535
# idx: 536
# idx: 537
# idx: 538
# idx: 539
# idx: 540
# idx: 541
# idx: 542
# idx: 543
# idx: 544
# idx: 545
# idx: 546
# idx: 547
# idx: 548
# idx: 549
# idx: 550
# idx: 551
# idx: 552
# idx: 553
# idx: 554
# idx: 555
# idx: 556
# idx: 557
# idx: 558
# idx: 559
# idx: 560
# idx: 561
# idx: 562
# idx: 563
# idx: 564
# idx: 565
# idx: 566
# idx: 567
# idx: 568
# idx: 569
# idx: 570
# idx: 571
# idx: 572
# idx: 573
# idx: 574
# idx: 575
# idx: 576
# Found Disconnected Node in the graph at index: 576
# idx: 577
# idx: 578
# idx: 579
# idx: 580
# idx: 581
# idx: 582
# idx: 583
# idx: 584
# idx: 585
# idx: 586
# idx: 587
# idx: 588
# idx: 589
# idx: 590
# idx: 591
# idx: 592
# idx: 593
# idx: 594
# idx: 595
# idx: 596
# idx: 597
# idx: 598
# idx: 599
# idx: 600
# idx: 601
# idx: 602
# idx: 603
# idx: 604
# idx: 605
# idx: 606
# idx: 607
# idx: 608
# idx: 609
# idx: 610
# idx: 611
# idx: 612
# idx: 613
# idx: 614
# idx: 615
# idx: 616
# idx: 617
# idx: 618
# idx: 619
# idx: 620
# idx: 621
# idx: 622
# idx: 623
# idx: 624
# idx: 625
# idx: 626
# idx: 627
# idx: 628
# idx: 629
# idx: 630
# idx: 631
# idx: 632
# idx: 633
# idx: 634
# idx: 635
# idx: 636
# idx: 637
# idx: 638
# idx: 639
# idx: 640
# idx: 641
# idx: 642
# idx: 643
# idx: 644
# idx: 645
# idx: 646
# idx: 647
# idx: 648
# idx: 649
# idx: 650
# idx: 651
# idx: 652
# idx: 653
# idx: 654
# idx: 655
# idx: 656
# idx: 657
# idx: 658
# idx: 659
# idx: 660
# idx: 661
# idx: 662
# idx: 663
# idx: 664
# idx: 665
# idx: 666
# idx: 667
# idx: 668
# idx: 669
# idx: 670
# idx: 671
# idx: 672
# idx: 673
# idx: 674
# idx: 675
# idx: 676
# idx: 677
# idx: 678
# Found Disconnected Node in the graph at index: 678
# idx: 679
# idx: 680
# idx: 681
# idx: 682
# idx: 683
# idx: 684
# idx: 685
# idx: 686
# idx: 687
# idx: 688
# idx: 689
# idx: 690
# idx: 691
# idx: 692
# idx: 693
# idx: 694
# idx: 695
# idx: 696
# idx: 697
# idx: 698
# idx: 699
# idx: 700
# idx: 701
# idx: 702
# idx: 703
# idx: 704
# idx: 705
# idx: 706
# idx: 707
# idx: 708
# idx: 709
# idx: 710
# idx: 711
# idx: 712
# idx: 713
# idx: 714
# idx: 715
# idx: 716
# idx: 717
# idx: 718
# idx: 719
# idx: 720
# idx: 721
# idx: 722
# idx: 723
# idx: 724
# idx: 725
# idx: 726
# idx: 727
# idx: 728
# idx: 729
# idx: 730
# idx: 731
# idx: 732
# idx: 733
# idx: 734
# idx: 735
# idx: 736
# idx: 737
# idx: 738
# idx: 739
# idx: 740
# idx: 741
# idx: 742
# idx: 743
# idx: 744
# Found Disconnected Node in the graph at index: 744
# idx: 745
# idx: 746
# idx: 747
# idx: 748
# idx: 749
# idx: 750
# idx: 751
# idx: 752
# idx: 753
# idx: 754
# idx: 755
# idx: 756
# idx: 757
# idx: 758
# idx: 759
# idx: 760
# idx: 761
# idx: 762
# idx: 763
# idx: 764
# idx: 765
# idx: 766
# idx: 767
# idx: 768
# idx: 769
# idx: 770
# idx: 771
# idx: 772
# idx: 773
# idx: 774
# idx: 775
# idx: 776
# idx: 777
# idx: 778
# idx: 779
# idx: 780
# idx: 781
# idx: 782
# idx: 783
# idx: 784
# idx: 785
# idx: 786
# idx: 787
# idx: 788
# idx: 789
# idx: 790
# idx: 791
# idx: 792
# idx: 793
# idx: 794
# idx: 795
# idx: 796
# idx: 797
# idx: 798
# idx: 799
# idx: 800
# idx: 801
# idx: 802
# idx: 803
# idx: 804
# idx: 805
# idx: 806
# idx: 807
# idx: 808
# idx: 809
# idx: 810
# idx: 811
# idx: 812
# idx: 813
# idx: 814
# idx: 815
# idx: 816
# idx: 817
# idx: 818
# idx: 819
# idx: 820
# idx: 821
# idx: 822
# idx: 823
# idx: 824
# idx: 825
# idx: 826
# idx: 827
# idx: 828
# idx: 829
# idx: 830
# Found Disconnected Node in the graph at index: 830
# idx: 831
# idx: 832
# idx: 833
# idx: 834
# idx: 835
# idx: 836
# idx: 837
# idx: 838
# idx: 839
# idx: 840
# idx: 841
# idx: 842
# idx: 843
# idx: 844
# idx: 845
# idx: 846
# idx: 847
# Found Disconnected Node in the graph at index: 847
# idx: 848
# idx: 849
# idx: 850
# idx: 851
# idx: 852
# idx: 853
# idx: 854
# idx: 855
# idx: 856
# idx: 857
# idx: 858
# idx: 859
# idx: 860
# idx: 861
# idx: 862
# Found Disconnected Node in the graph at index: 862
# idx: 863
# Found Disconnected Node in the graph at index: 863
# idx: 864
# idx: 865
# idx: 866
# idx: 867
# idx: 868
# idx: 869
# idx: 870
# idx: 871
# idx: 872
# idx: 873
# idx: 874
# idx: 875
# idx: 876
# idx: 877
# idx: 878
# idx: 879
# idx: 880
# idx: 881
# idx: 882
# idx: 883
# idx: 884
# idx: 885
# idx: 886
# idx: 887
# idx: 888
# idx: 889
# idx: 890
# idx: 891
# idx: 892
# idx: 893
# idx: 894
# idx: 895
# idx: 896
# idx: 897
# idx: 898
# idx: 899
# idx: 900
# idx: 901
# idx: 902
# idx: 903
# idx: 904
# idx: 905
# idx: 906
# idx: 907
# idx: 908
# idx: 909
# idx: 910
# idx: 911
# idx: 912
# idx: 913
# idx: 914
# idx: 915
# idx: 916
# idx: 917
# idx: 918
# idx: 919
# idx: 920
# idx: 921
# idx: 922
# idx: 923
# idx: 924
# idx: 925
# idx: 926
# idx: 927
# idx: 928
# idx: 929
# idx: 930
# idx: 931
# idx: 932
# idx: 933
# idx: 934
# idx: 935
# idx: 936
# idx: 937
# idx: 938
# idx: 939
# idx: 940
# idx: 941
# idx: 942
# idx: 943
# idx: 944
# idx: 945
# idx: 946
# idx: 947
# idx: 948
# idx: 949
# idx: 950
# idx: 951
# idx: 952
# idx: 953
# idx: 954
# idx: 955
# idx: 956
# idx: 957
# idx: 958
# idx: 959
# idx: 960
# idx: 961
# idx: 962
# idx: 963
# idx: 964
# idx: 965
# idx: 966
# idx: 967
# idx: 968
# idx: 969
# idx: 970
# idx: 971
# idx: 972
# idx: 973
# idx: 974
# idx: 975
# idx: 976
# idx: 977
# idx: 978
# idx: 979
# idx: 980
# idx: 981
# idx: 982
# idx: 983
# idx: 984
# idx: 985
# idx: 986
# idx: 987
# Found Disconnected Node in the graph at index: 987
# idx: 988
# idx: 989
# idx: 990
# idx: 991
# idx: 992
# idx: 993
# idx: 994
# idx: 995
# idx: 996
# idx: 997
# idx: 998
# idx: 999
# idx: 1000
# idx: 1001
# idx: 1002
# idx: 1003
# idx: 1004
# idx: 1005
# idx: 1006
# idx: 1007
# idx: 1008
# idx: 1009
# idx: 1010
# idx: 1011
# idx: 1012
# idx: 1013
# idx: 1014
# idx: 1015
# idx: 1016
# idx: 1017
# idx: 1018
# idx: 1019
# idx: 1020
# idx: 1021
# idx: 1022
# idx: 1023
# Found Disconnected Node in the graph at index: 1023
# idx: 1024
# idx: 1025
# idx: 1026
# idx: 1027
# idx: 1028
# idx: 1029
# idx: 1030
# idx: 1031
# idx: 1032
# idx: 1033
# idx: 1034
# idx: 1035
# idx: 1036
# idx: 1037
# idx: 1038
# idx: 1039
# idx: 1040
# idx: 1041
# idx: 1042
# idx: 1043
# Found Disconnected Node in the graph at index: 1043
# idx: 1044
# idx: 1045
# idx: 1046
# idx: 1047
# idx: 1048
# idx: 1049
# idx: 1050
# Found Disconnected Node in the graph at index: 1050
# idx: 1051
# idx: 1052
# idx: 1053
# idx: 1054
# Found Disconnected Node in the graph at index: 1054
# idx: 1055
# idx: 1056
# Found Disconnected Node in the graph at index: 1056
# idx: 1057
# idx: 1058
# idx: 1059
# idx: 1060
# idx: 1061
# idx: 1062
# idx: 1063
# idx: 1064
# idx: 1065
# idx: 1066
# idx: 1067
# idx: 1068
# idx: 1069
# idx: 1070
# idx: 1071
# idx: 1072
# idx: 1073
# idx: 1074
# idx: 1075
# idx: 1076
# idx: 1077
# idx: 1078
# idx: 1079
# idx: 1080
# idx: 1081
# idx: 1082
# idx: 1083
# idx: 1084
# idx: 1085
# idx: 1086
# idx: 1087
# idx: 1088
# idx: 1089
# idx: 1090
# idx: 1091
# idx: 1092
# idx: 1093
# idx: 1094
# idx: 1095
# idx: 1096
# idx: 1097
# idx: 1098
# idx: 1099
# idx: 1100
# idx: 1101
# idx: 1102
# idx: 1103
# idx: 1104
# idx: 1105
# idx: 1106
# idx: 1107
# idx: 1108
# idx: 1109
# idx: 1110
# idx: 1111
# idx: 1112
# idx: 1113
# idx: 1114
# idx: 1115
# idx: 1116
# idx: 1117
# idx: 1118
# idx: 1119
# idx: 1120
# idx: 1121
# idx: 1122
# idx: 1123
# idx: 1124
# idx: 1125
# idx: 1126
# idx: 1127
# idx: 1128
# idx: 1129
# idx: 1130
# idx: 1131
# idx: 1132
# idx: 1133
# idx: 1134
# idx: 1135
# idx: 1136
# idx: 1137
# idx: 1138
# idx: 1139
# idx: 1140
# idx: 1141
# idx: 1142
# idx: 1143
# idx: 1144
# idx: 1145
# idx: 1146
# idx: 1147
# idx: 1148
# idx: 1149
# idx: 1150
# idx: 1151
# idx: 1152
# Found Disconnected Node in the graph at index: 1152
# idx: 1153
# idx: 1154
# idx: 1155
# idx: 1156
# idx: 1157
# idx: 1158
# idx: 1159
# idx: 1160
# idx: 1161
# idx: 1162
# idx: 1163
# idx: 1164
# idx: 1165
# idx: 1166
# idx: 1167
# idx: 1168
# idx: 1169
# idx: 1170
# idx: 1171
# idx: 1172
# idx: 1173
# idx: 1174
# idx: 1175
# idx: 1176
# idx: 1177
# idx: 1178
# idx: 1179
# idx: 1180
# idx: 1181
# idx: 1182
# idx: 1183
# idx: 1184
# idx: 1185
# idx: 1186
# idx: 1187
# idx: 1188
# idx: 1189
# idx: 1190
# idx: 1191
# idx: 1192
# idx: 1193
# idx: 1194
# idx: 1195
# idx: 1196
# idx: 1197
# idx: 1198
# idx: 1199
# idx: 1200
# idx: 1201
# idx: 1202
# idx: 1203
# idx: 1204
# idx: 1205
# idx: 1206
# idx: 1207
# idx: 1208
# idx: 1209
# idx: 1210
# idx: 1211
# idx: 1212
# idx: 1213
# idx: 1214
# idx: 1215
# idx: 1216
# idx: 1217
# idx: 1218
# idx: 1219
# idx: 1220
# idx: 1221
# idx: 1222
# idx: 1223
# idx: 1224
# idx: 1225
# idx: 1226
# idx: 1227
# idx: 1228
# idx: 1229
# idx: 1230
# idx: 1231
# idx: 1232
# idx: 1233
# idx: 1234
# idx: 1235
# idx: 1236
# idx: 1237
# idx: 1238
# idx: 1239
# idx: 1240
# idx: 1241
# idx: 1242
# idx: 1243
# idx: 1244
# idx: 1245
# idx: 1246
# idx: 1247
# idx: 1248
# idx: 1249
# idx: 1250
# idx: 1251
# idx: 1252
# idx: 1253
# idx: 1254
# idx: 1255
# idx: 1256
# idx: 1257
# idx: 1258
# idx: 1259
# idx: 1260
# idx: 1261
# idx: 1262
# idx: 1263
# idx: 1264
# idx: 1265
# idx: 1266
# idx: 1267
# idx: 1268
# idx: 1269
# idx: 1270
# idx: 1271
# idx: 1272
# idx: 1273
# idx: 1274
# idx: 1275
# Found Disconnected Node in the graph at index: 1275
# idx: 1276
# idx: 1277
# idx: 1278
# idx: 1279
# idx: 1280
# idx: 1281
# idx: 1282
# idx: 1283
# idx: 1284
# idx: 1285
# idx: 1286
# idx: 1287
# idx: 1288
# idx: 1289
# idx: 1290
# idx: 1291
# idx: 1292
# idx: 1293
# idx: 1294
# idx: 1295
# idx: 1296
# idx: 1297
# idx: 1298
# idx: 1299
# idx: 1300
# idx: 1301
# idx: 1302
# idx: 1303
# idx: 1304
# Found Disconnected Node in the graph at index: 1304
# idx: 1305
# idx: 1306
# idx: 1307
# idx: 1308
# idx: 1309
# idx: 1310
# idx: 1311
# idx: 1312
# idx: 1313
# idx: 1314
# idx: 1315
# idx: 1316
# idx: 1317
# idx: 1318
# idx: 1319
# idx: 1320
# idx: 1321
# idx: 1322
# idx: 1323
# idx: 1324
# idx: 1325
# idx: 1326
# idx: 1327
# idx: 1328
# idx: 1329
# idx: 1330
# idx: 1331
# idx: 1332
# idx: 1333
# idx: 1334
# idx: 1335
# idx: 1336
# idx: 1337
# idx: 1338
# idx: 1339
# idx: 1340
# idx: 1341
# idx: 1342
# idx: 1343
# idx: 1344
# idx: 1345
# idx: 1346
# idx: 1347
# idx: 1348
# idx: 1349
# idx: 1350
# idx: 1351
# idx: 1352
# idx: 1353
# idx: 1354
# idx: 1355
# idx: 1356
# idx: 1357
# idx: 1358
# idx: 1359
# idx: 1360
# idx: 1361
# idx: 1362
# idx: 1363
# idx: 1364
# idx: 1365
# idx: 1366
# idx: 1367
# idx: 1368
# idx: 1369
# idx: 1370
# idx: 1371
# idx: 1372
# idx: 1373
# idx: 1374
# idx: 1375
# idx: 1376
# idx: 1377
# idx: 1378
# idx: 1379
# idx: 1380
# idx: 1381
# idx: 1382
# idx: 1383
# idx: 1384
# idx: 1385
# idx: 1386
# idx: 1387
# idx: 1388
# idx: 1389
# idx: 1390
# idx: 1391
# idx: 1392
# idx: 1393
# idx: 1394
# idx: 1395
# idx: 1396
# idx: 1397
# idx: 1398
# idx: 1399
# idx: 1400
# idx: 1401
# idx: 1402
# idx: 1403
# idx: 1404
# idx: 1405
# idx: 1406
# idx: 1407
# idx: 1408
# idx: 1409
# idx: 1410
# idx: 1411
# idx: 1412
# idx: 1413
# idx: 1414
# idx: 1415
# idx: 1416
# idx: 1417
# idx: 1418
# idx: 1419
# idx: 1420
# idx: 1421
# Found Disconnected Node in the graph at index: 1421
# idx: 1422
# idx: 1423
# idx: 1424
# idx: 1425
# idx: 1426
# idx: 1427
# idx: 1428
# idx: 1429
# idx: 1430
# idx: 1431
# idx: 1432
# idx: 1433
# idx: 1434
# idx: 1435
# idx: 1436
# idx: 1437
# idx: 1438
# idx: 1439
# idx: 1440
# idx: 1441
# idx: 1442
# idx: 1443
# idx: 1444
# idx: 1445
# idx: 1446
# idx: 1447
# idx: 1448
# idx: 1449
# idx: 1450
# idx: 1451
# idx: 1452
# idx: 1453
# idx: 1454
# idx: 1455
# idx: 1456
# idx: 1457
# idx: 1458
# idx: 1459
# idx: 1460
# idx: 1461
# idx: 1462
# idx: 1463
# idx: 1464
# idx: 1465
# idx: 1466
# idx: 1467
# idx: 1468
# idx: 1469
# idx: 1470
# idx: 1471
# idx: 1472
# idx: 1473
# idx: 1474
# idx: 1475
# idx: 1476
# idx: 1477
# idx: 1478
# idx: 1479
# idx: 1480
# idx: 1481
# idx: 1482
# idx: 1483
# idx: 1484
# idx: 1485
# idx: 1486
# idx: 1487
# idx: 1488
# idx: 1489
# idx: 1490
# idx: 1491
# idx: 1492
# idx: 1493
# idx: 1494
# idx: 1495
# idx: 1496
# idx: 1497
# idx: 1498
# idx: 1499
# idx: 1500
# idx: 1501
# idx: 1502
# idx: 1503
# idx: 1504
# idx: 1505
# idx: 1506
# idx: 1507
# idx: 1508
# idx: 1509
# idx: 1510
# idx: 1511
# idx: 1512
# idx: 1513
# idx: 1514
# idx: 1515
# idx: 1516
# idx: 1517
# idx: 1518
# idx: 1519
# idx: 1520
# idx: 1521
# idx: 1522
# idx: 1523
# idx: 1524
# idx: 1525
# idx: 1526
# idx: 1527
# idx: 1528
# idx: 1529
# idx: 1530
# idx: 1531
# idx: 1532
# idx: 1533
# idx: 1534
# idx: 1535
# idx: 1536
# idx: 1537
# idx: 1538
# idx: 1539
# idx: 1540
# idx: 1541
# idx: 1542
# idx: 1543
# idx: 1544
# idx: 1545
# idx: 1546
# idx: 1547
# idx: 1548
# idx: 1549
# idx: 1550
# idx: 1551
# idx: 1552
# idx: 1553
# idx: 1554
# idx: 1555
# idx: 1556
# idx: 1557
# idx: 1558
# idx: 1559
# idx: 1560
# idx: 1561
# idx: 1562
# idx: 1563
# idx: 1564
# idx: 1565
# idx: 1566
# idx: 1567
# idx: 1568
# idx: 1569
# idx: 1570
# idx: 1571
# idx: 1572
# idx: 1573
# idx: 1574
# idx: 1575
# idx: 1576
# idx: 1577
# idx: 1578
# idx: 1579
# idx: 1580
# idx: 1581
# idx: 1582
# idx: 1583
# idx: 1584
# idx: 1585
# idx: 1586
# idx: 1587
# idx: 1588
# idx: 1589
# idx: 1590
# idx: 1591
# idx: 1592
# idx: 1593
# idx: 1594
# idx: 1595
# Found Disconnected Node in the graph at index: 1595
# idx: 1596
# idx: 1597
# idx: 1598
# idx: 1599
# idx: 1600
# idx: 1601
# idx: 1602
# idx: 1603
# idx: 1604
# idx: 1605
# idx: 1606
# idx: 1607
# idx: 1792
# idx: 1793
# idx: 1794
# idx: 1795
# idx: 1796
# idx: 1797
# idx: 1798
# idx: 1799
# idx: 1800
# idx: 1801
# idx: 1802
# idx: 1803
# idx: 1804
# idx: 1805
# idx: 1806
# idx: 1807
# idx: 1808
# idx: 1809
# idx: 1810
# idx: 1811
# idx: 1812
# idx: 1813
# idx: 1814
# idx: 1815
# idx: 1816
# idx: 1817
# idx: 1818
# idx: 1819
# idx: 1820
# idx: 1821
# idx: 1822
# idx: 1823
# idx: 1824
# idx: 1825
# idx: 1826
# idx: 1827
# idx: 1828
# idx: 1829
# idx: 1830
# idx: 1831
# idx: 1832
# idx: 1833
# idx: 1834
# idx: 1835
# idx: 1836
# idx: 1837
# idx: 1838
# idx: 1839
# idx: 1840
# idx: 1841
# idx: 1842
# idx: 1843
# idx: 1844
# idx: 1845
# idx: 1846
# idx: 1847
# idx: 1848
# idx: 1849
# idx: 1850
# idx: 1851
# idx: 1852
# idx: 1853
# idx: 1854
# idx: 1855
# idx: 1856
# idx: 1857
# idx: 1858
# idx: 1859
# idx: 1860
# idx: 1861
# idx: 1862
# idx: 1863
# idx: 1864
# idx: 1865
# idx: 1866
# idx: 1867
# idx: 1868
# idx: 1869
# Found Disconnected Node in the graph at index: 1869
# idx: 1870
# idx: 1871
# idx: 1872
# idx: 1873
# idx: 1874
# idx: 1875
# idx: 1876
# idx: 1877
# idx: 1878
# idx: 1879
# idx: 1880
# idx: 1881
# idx: 1882
# idx: 1883
# idx: 1884
# idx: 1885
# idx: 1886
# idx: 1887
# idx: 1888
# idx: 1889
# idx: 1890
# idx: 1891
# idx: 1892
# idx: 1893
# idx: 1894
# idx: 1895
# idx: 1896
# idx: 1897
# idx: 1898
# idx: 1899
# idx: 1900
# idx: 1901
# idx: 1902
# idx: 1903
# idx: 1904
# idx: 1905
# idx: 1906
# idx: 1907
# idx: 1908
# idx: 1909
# idx: 1910
# idx: 1911
# idx: 1912
# idx: 1913
# idx: 1914
# Found Disconnected Node in the graph at index: 1914
# idx: 1915
# idx: 1916
# idx: 1917
# idx: 1918
# idx: 1919
# idx: 1920
# idx: 1921
# idx: 1922
# idx: 1923
# idx: 1924
# idx: 1925
# idx: 1926
# idx: 1927
# idx: 1928
# idx: 1929
# idx: 1930
# idx: 1931
# Found Disconnected Node in the graph at index: 1931
# idx: 1932
# idx: 1933
# idx: 1934
# idx: 1935
# idx: 1936
# idx: 1937
# idx: 1938
# idx: 1939
# idx: 1940
# idx: 1941
# idx: 1942
# idx: 1943
# idx: 1944
# idx: 1945
# idx: 1946
# idx: 1947
# idx: 1948
# idx: 1949
# idx: 1950
# idx: 1951
# idx: 1952
# idx: 1953
# idx: 1954
# idx: 1955
# idx: 1956
# idx: 1957
# idx: 1958
# idx: 1959
# idx: 1960
# idx: 1961
# idx: 1962
# idx: 1963
# idx: 1964
# idx: 1965
# idx: 1966
# idx: 1967
# idx: 1968
# idx: 1969
# idx: 1970
# idx: 1971
# idx: 1972
# idx: 1973
# idx: 1974
# idx: 1975
# idx: 1976
# idx: 1977
# idx: 4958
# idx: 4959
# idx: 4960
# idx: 4961
# idx: 4962
# idx: 4963
# idx: 4964
# idx: 4965
# idx: 4966
# idx: 4967
# idx: 4968
# idx: 4969
# idx: 4970
# idx: 4971
# idx: 4972
# idx: 4973
# idx: 4974
# idx: 4975
# idx: 4976
# idx: 4977
# idx: 4978
# idx: 4979
# idx: 4980
# idx: 4981
# idx: 4982
# idx: 4983
# idx: 4984
# idx: 4985
# idx: 4986
# idx: 4987
# idx: 4988
# idx: 4989
# idx: 4990
# idx: 4991
# idx: 4992
# idx: 4993
# idx: 4994
# idx: 4995
# idx: 4996
# idx: 4997
# idx: 4998
# idx: 4999
# idx: 5000

# %%
# connectiong to arangodb
# Initialize the ArangoDB client.
client = ArangoClient("http://127.0.0.1:8529")

# %%
## Connect to the database
#amazon_db = oasis.connect_python_arango(login)
amazon_db = client.db('_system', username='root', password='amritsar')

# %%
test_idx_lb = 235938
test_idx_mb = test_idx_lb + len(layer_3_embs)
test_idx_ub = 2449028

# %%
# load dataset
#! ./arangorestore -c none --create-collection true --server.endpoint "tcp://127.0.0.1:8529" --server.username "root" --server.database "_system" --server.password "amritsar" --default-replication-factor 3  --input-directory "./ogbn-product_dataset"

# %%
batch = []
BATCH_SIZE = 250
batch_idx = 1
index = 0
# collection in which we will store are inference results
product_collection = amazon_db["Products"]

# %% [markdown]
# In the below cell we will update the amazon product recommendation graph (obgn-products) dataset stored inside the ArangoDB with the node embeddings and their corresponding product category predictions for the 5000 test nodes.

# %%
for idx in range(test_idx_lb, test_idx_mb):
    update_doc = {}
    product_id = "Products/" + str(idx)
    update_doc["_id"] = product_id
    if layer_3_embs[index] == "Disconnected Node":
        update_doc["predicted_node_embeddings"] = layer_3_embs[index]
        update_doc["predicted_product"] = str(-1)
    else:
        update_doc["predicted_node_embeddings"] = layer_3_embs[index].tolist()
        update_doc["predicted_product"] = str(label_mapping[np.argmax(layer_3_embs[index], axis=-1)])
    batch.append(update_doc)
    last_record = (idx == (test_idx_mb - 1))
    index +=1
    
    if index % BATCH_SIZE == 0:
        print("Inserting batch %d" % (batch_idx))
        batch_idx += 1
        product_collection.update_many(batch)
        batch = []   
    if last_record and len(batch) > 0:
        print("Inserting batch the last batch!")
        product_collection.update_many(batch)
# Out:
# Inserting batch 1
# Inserting batch 2
# Inserting batch 3
# Inserting batch 4
# Inserting batch 5
# Inserting batch 6
# Inserting batch 7
# Inserting batch 8
# Inserting batch 9
# Inserting batch 10
# Inserting batch 11
# Inserting batch 12
# Inserting batch 13
# Inserting batch 14
# Inserting batch 15
# Inserting batch 16
# Inserting batch 17
# Inserting batch 18
# Inserting batch 19
# Inserting batch 20

# %% [markdown]
# ## Amazon Product Recommendation with AQL
# Products which can be bought together with a query product

# %%
# product ids for demo 235940, 240930
cursor = amazon_db.aql.execute(
"""
  FOR p in Products
    FILTER p._id == "Products/236435"
    RETURN { "predicted_node_embeddings": p.predicted_node_embeddings, "product_cat": p.product_cat }
""")

# Iterate through the result cursor
for doc in cursor:
  print(doc)
# Out:
# {'predicted_node_embeddings': [8.11427116394043, 1.2199492454528809, -3.4377615451812744, -2.5239882469177246, -3.2495641708374023, 5.2369794845581055, -1.8155913352966309, -8.527416229248047, -4.056517601013184, -1.9635710716247559, 0.19732767343521118, -2.9490034580230713, -1.4104312658309937, -9.393174171447754, -11.7564058303833, -6.5331902503967285, -2.5783517360687256, -4.2324137687683105, 3.3259811401367188, 0.030963152647018433, -4.7573771476745605, 3.299964427947998, -12.81488037109375, -0.5681211948394775, -5.670832633972168, 1.744966745376587, 1.7140165567398071, -10.516529083251953, -7.2565412521362305, -21.127893447875977, -6.552777290344238, -10.345855712890625, -8.504383087158203, -11.93044662475586, -14.149519920349121, -14.586654663085938, -6.9217448234558105, -7.073517799377441, -14.168991088867188, -11.582767486572266, -11.457265853881836, -16.460329055786133, -12.390432357788086, -12.25572395324707, -12.473586082458496, -12.95902156829834, -12.110896110534668], 'product_cat': 'Home & Kitchen'}

# %%
cursor = amazon_db.aql.execute(
"""
LET descr_emb = (
  FOR p in Products
    FILTER p._id == "Products/236435"
    FOR j in RANGE(0, 46)
      RETURN TO_NUMBER(NTH(p.predicted_node_embeddings,j))
)

LET descr_mag = (
  SQRT(SUM(
    FOR i IN RANGE(0, 47)
      RETURN POW(TO_NUMBER(NTH(descr_emb, i)), 2)
  ))
)

LET dau = (

    FOR v in Products
    FILTER HAS(v, "predicted_node_embeddings")

    LET v_mag = (SQRT(SUM(
      FOR k IN RANGE(0, 47)
        RETURN POW(TO_NUMBER(NTH(v.predicted_node_embeddings, k)), 2)
    )))

    LET numerator = (SUM(
      FOR i in RANGE(0,46)
          RETURN TO_NUMBER(NTH(descr_emb, i)) * TO_NUMBER(NTH(v.predicted_node_embeddings, i))
    ))

    LET cos_sim = (numerator)/(descr_mag * v_mag)

    RETURN {"product": v._id, "product_cat": v.product_cat, "cos_sim": cos_sim}

    )

FOR du in dau
    SORT du.cos_sim DESC
    LIMIT 5000
    RETURN {"product_cat": du.product_cat, "cos_sim": du.cos_sim} 
""")

# %%
# Iterate through the result cursor
for doc in cursor:
    print(doc)
# Out:
# {'product_cat': 'Home & Kitchen', 'cos_sim': 1}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9915181195954686}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9903672509511374}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9898367275336624}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9896782150608073}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9882337658793278}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9880318458111959}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9872162913201172}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9859483691799504}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9858877208046664}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9853313674545409}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9851588622389956}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9850942093242058}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.984943823143214}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9838077985619076}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9837282886335602}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9837011056040137}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9834617183027786}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9833406916031223}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9833121161528898}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9830256520232777}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9824556118108361}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9823023343994985}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9819430079114447}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9813338569969006}
# {'product_cat': 'Automotive', 'cos_sim': 0.9809705960628884}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9808991240082706}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9808862805694663}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9807942633934745}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9805234606698688}
# {'product_cat': 'nan', 'cos_sim': 0.9801337193071067}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9799221012531824}
# {'product_cat': 'Baby', 'cos_sim': 0.9795062556428139}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9790133844041194}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9789149809005274}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9789087285531077}
# {'product_cat': 'Baby', 'cos_sim': 0.9785636484753883}
# {'product_cat': 'Baby', 'cos_sim': 0.9782409955887392}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9780479705942597}
# {'product_cat': 'Baby', 'cos_sim': 0.9778916875555936}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9776671606454095}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9775930902439722}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9774908123849951}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9773942136443401}
# {'product_cat': 'Baby', 'cos_sim': 0.9772138753989806}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9771999389998465}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9770180913692844}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9770082651985509}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9767582009556203}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9764051938716612}
# {'product_cat': 'Baby', 'cos_sim': 0.9755853233824054}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9754625451068444}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9751123527825275}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9749535380848258}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9745675899378579}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9745177426429188}
# {'product_cat': 'Baby', 'cos_sim': 0.9744799221122487}
# {'product_cat': 'Baby', 'cos_sim': 0.9744649620724529}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9741046585269901}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9740987533331891}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9735810693504359}
# {'product_cat': 'Baby', 'cos_sim': 0.9735412556695315}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.973404741673305}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9732324478275333}
# {'product_cat': 'Baby', 'cos_sim': 0.973115937547654}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9730227661242664}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9729190035425411}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9727287336955356}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9726036421714653}
# {'product_cat': 'Baby', 'cos_sim': 0.972526548026511}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9724376591064484}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9723799771901118}
# {'product_cat': 'Appliances', 'cos_sim': 0.9721783809760952}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9721329956456877}
# {'product_cat': 'Office Products', 'cos_sim': 0.9718150519368037}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9717342571186246}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9715613769003392}
# {'product_cat': 'Baby', 'cos_sim': 0.9714168213583704}
# {'product_cat': 'Office Products', 'cos_sim': 0.9707881270713771}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9707186655345268}
# {'product_cat': 'Office Products', 'cos_sim': 0.9706268475885687}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9706159323730955}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9706032514163064}
# {'product_cat': 'Baby Products', 'cos_sim': 0.970283039362551}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9702476332686826}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9701519378514001}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.969870728602229}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9697318754350542}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9696793002355454}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9695761555264312}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.969524843510186}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9693745226488233}
# {'product_cat': 'Beauty', 'cos_sim': 0.9691327197285322}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9691013622764977}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9690770574655025}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.96880130169433}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9687872992174803}
# {'product_cat': 'Office Products', 'cos_sim': 0.9684407916600422}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9684293820097143}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9684232793295574}
# {'product_cat': 'nan', 'cos_sim': 0.9681440863507965}
# {'product_cat': 'Baby', 'cos_sim': 0.9680970247184071}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9680005310412145}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9679990484917167}
# {'product_cat': 'Kitchen & Dining', 'cos_sim': 0.9677806147187399}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9676105136050454}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9674050664942513}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9671817551995153}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9669854102035642}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.966436816376931}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9663881758320092}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.966347381601996}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9661036333557864}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9658057816128602}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.965386826879988}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9653752970342944}
# {'product_cat': 'Baby', 'cos_sim': 0.9653074539631371}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9652412072828401}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9651651272697356}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9650044100204999}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9649529028998388}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9649370363196103}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9647148223884761}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9645328792124966}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9644800426557564}
# {'product_cat': 'Office Products', 'cos_sim': 0.9642502474143554}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9641701830038087}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9641380875047919}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9641148872507063}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9640343214936463}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9640280814123848}
# {'product_cat': 'Baby', 'cos_sim': 0.963707954259706}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9635846241055687}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9634877298227806}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9633348958665401}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9631830027557666}
# {'product_cat': 'Baby', 'cos_sim': 0.9629391289358434}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9627286178297121}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9620853310271305}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9620726843946292}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9616308188942401}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.960782562878697}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9603239546953388}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.960143192619362}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.960140688087853}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9596971759623155}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.959541884841958}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9595263930755814}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9594400944666005}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9593990684293293}
# {'product_cat': 'Office Products', 'cos_sim': 0.9592016309400472}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9590959313089348}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9590713489033778}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9590321894671052}
# {'product_cat': 'Grocery & Gourmet Food', 'cos_sim': 0.9588309709659849}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9588131044658048}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9587004747125725}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9586926103867685}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9586749974267565}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9583811409720517}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9583621155469734}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9582961693034603}
# {'product_cat': 'Automotive', 'cos_sim': 0.9582443674059703}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9580970750171225}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.958086531676137}
# {'product_cat': 'Baby', 'cos_sim': 0.9580470098190256}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9579924679218386}
# {'product_cat': 'Office Products', 'cos_sim': 0.9579806408350884}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9579092522133565}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9578737413136712}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9577976358723538}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.957797350362987}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9576856661564142}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9576451913072369}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9576388631597358}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9576054426163447}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9574906736764399}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9574639172929761}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9572135930982154}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9571970907099601}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9571906767998591}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9571061593485993}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9570786579156882}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9569860350348864}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9568012250323309}
# {'product_cat': 'nan', 'cos_sim': 0.9567930751456324}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9566310234021004}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9565647718764192}
# {'product_cat': 'Office Products', 'cos_sim': 0.9564048693515373}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9563823637641776}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.95627867460504}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9562254028987307}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9562227869779171}
# {'product_cat': 'Office Products', 'cos_sim': 0.9561608555500778}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9559550898215271}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9559460000008346}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9558455123434411}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9557407803707758}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9556518958847079}
# {'product_cat': 'Office Products', 'cos_sim': 0.9555870600541871}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9554691342138275}
# {'product_cat': 'Office Products', 'cos_sim': 0.9553424707371962}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9553142518961695}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9551317883904668}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9550912802648518}
# {'product_cat': 'Automotive', 'cos_sim': 0.9549861519493471}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.954724525613794}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9546862403923433}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9544492488768538}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9542242141485459}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9542074549138632}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9541251498276638}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9541120763029309}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9539921803555339}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9539398417945243}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9539300880962017}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9538821958270263}
# {'product_cat': 'Baby', 'cos_sim': 0.9537022298144339}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9536890325819126}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9536241424955266}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9536179132523906}
# {'product_cat': 'nan', 'cos_sim': 0.9536051370849262}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9535260247550835}
# {'product_cat': 'Baby', 'cos_sim': 0.9533432723343332}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9532335041444249}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9531686826343793}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9531430648360204}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9529780415741959}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9528404633990175}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.952779873499376}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9527309184503128}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9524691958916324}
# {'product_cat': 'Office Products', 'cos_sim': 0.9523299325139017}
# {'product_cat': 'Grocery & Gourmet Food', 'cos_sim': 0.952164619565244}
# {'product_cat': 'Office Products', 'cos_sim': 0.9521144274937706}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9519792927358479}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9519540320292698}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9518824509137699}
# {'product_cat': 'Baby', 'cos_sim': 0.9518747598107777}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9518700658599417}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9517453295500485}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9516628481088765}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9515519211073546}
# {'product_cat': 'Automotive', 'cos_sim': 0.9513224949035437}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9513055104197228}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9512201424085547}
# {'product_cat': 'Office Products', 'cos_sim': 0.9511102408682912}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9510966361153186}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9510896497945279}
# {'product_cat': 'Baby', 'cos_sim': 0.9508857945423095}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.950613970487001}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.950468102346399}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9503344424360594}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.950323992823418}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.950316747545528}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9501500438630607}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9500985503157002}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9499902737445106}
# {'product_cat': 'Baby', 'cos_sim': 0.949833124751497}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9498187756842295}
# {'product_cat': 'Office Products', 'cos_sim': 0.9497849551284964}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9497762557969542}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9497600081558425}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9496623517447292}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9495867320356786}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9495070049662349}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9492836133828779}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9492409003919671}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9491915004516106}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9491691103448956}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9490453037135965}
# {'product_cat': 'Baby', 'cos_sim': 0.948993454064255}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9489480605266111}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9488930091321511}
# {'product_cat': 'nan', 'cos_sim': 0.9488618522188765}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9487956926176631}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9487750458101493}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9487654706595773}
# {'product_cat': 'Office Products', 'cos_sim': 0.9486878914206635}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9486644971482581}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9486065260212995}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9485463491792351}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9484317641149904}
# {'product_cat': 'Baby', 'cos_sim': 0.948121285307236}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9480502117820716}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9479531706188695}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.947948614898505}
# {'product_cat': 'Office Products', 'cos_sim': 0.9479047195348691}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9476079359595677}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9475539371792528}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9475182366592074}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9474454970893608}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9474138695964889}
# {'product_cat': 'Office Products', 'cos_sim': 0.9473691270089362}
# {'product_cat': 'nan', 'cos_sim': 0.9472230357229459}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9472200059914448}
# {'product_cat': 'nan', 'cos_sim': 0.9472181895171136}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9471794235329045}
# {'product_cat': 'nan', 'cos_sim': 0.9471021436814813}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9470331171332447}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9469929066888393}
# {'product_cat': 'Office Products', 'cos_sim': 0.946987532368725}
# {'product_cat': 'Office Products', 'cos_sim': 0.9467116801668066}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9466676590821559}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.946614677457621}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': 0.9464787714043755}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.946398835308877}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9463532409888117}
# {'product_cat': 'nan', 'cos_sim': 0.9462565961390504}
# {'product_cat': 'Baby', 'cos_sim': 0.9458321235576457}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9457208612709888}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9456709087143459}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9454457921004563}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9454329153342129}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9454313109997421}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.945310008275155}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9452996748226438}
# {'product_cat': 'Office Products', 'cos_sim': 0.9452898203476502}
# {'product_cat': 'Office Products', 'cos_sim': 0.9452581587309425}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9450970936419881}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9450540076268965}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9450480315217331}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9447982590661298}
# {'product_cat': 'Office Products', 'cos_sim': 0.9447543616852803}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9446523557178645}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9445411303901795}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9444491515123041}
# {'product_cat': 'Baby', 'cos_sim': 0.9444468814641199}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9442808006544031}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9440652164596731}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9440170537504521}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9439601346298273}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9439051922974433}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9438879479797005}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9438660342248929}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9438427669122915}
# {'product_cat': 'Baby', 'cos_sim': 0.9437676839292046}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9437591954264456}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9437434841605858}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9436515515602766}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.94363130102893}
# {'product_cat': 'Baby', 'cos_sim': 0.943473124060329}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9433993578706604}
# {'product_cat': 'Office Products', 'cos_sim': 0.9433952893592277}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.943336236809964}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9432595340807094}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': 0.9432324155423841}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9431480262664511}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.943108208690271}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9430665738680956}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9430583599439688}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9429884336924735}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9428646428079275}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9427711493787374}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9427433848461441}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9427259735631301}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9427161692880511}
# {'product_cat': 'Office Products', 'cos_sim': 0.9424889750009049}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9424014442729717}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9423006477629371}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9422569308515681}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9421523917026129}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9420340131759157}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9419265288250394}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9419213327507843}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9418350249530794}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9417698136431741}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9416564760288831}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9416483338795956}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9414726545491542}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9414666956552785}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9413678669460578}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9412263098644695}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.941207912683894}
# {'product_cat': 'Baby', 'cos_sim': 0.9411854801879838}
# {'product_cat': 'Office Products', 'cos_sim': 0.9410939812959781}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9410788746294382}
# {'product_cat': 'Office Products', 'cos_sim': 0.9409490523293653}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9408575263816131}
# {'product_cat': 'nan', 'cos_sim': 0.9407837024002386}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9407830186249346}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9407284181576413}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9406231375114456}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9405064471677959}
# {'product_cat': 'Baby', 'cos_sim': 0.9403627551224737}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9403318367370922}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9403242223048657}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9402751728556751}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9402094040090988}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9401734842447618}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9401479739223293}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9400690719534209}
# {'product_cat': 'Baby', 'cos_sim': 0.939855780404066}
# {'product_cat': 'Office Products', 'cos_sim': 0.9396583146338359}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9394923136579596}
# {'product_cat': 'nan', 'cos_sim': 0.9394279369774551}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9390676294748612}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9390588991560006}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9390408309772093}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9390254943131746}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9389694618881779}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9389164005622124}
# {'product_cat': 'Automotive', 'cos_sim': 0.9389080127883138}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9388733091207055}
# {'product_cat': 'Automotive', 'cos_sim': 0.9386398889376072}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9385653343455156}
# {'product_cat': 'Baby', 'cos_sim': 0.9382015873158838}
# {'product_cat': 'Office Products', 'cos_sim': 0.9381826558799701}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9381745138630367}
# {'product_cat': 'Baby', 'cos_sim': 0.938163498964158}
# {'product_cat': 'Office Products', 'cos_sim': 0.9379962087238588}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.937978050937933}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9378358555168499}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.937768049314715}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9377251309817225}
# {'product_cat': 'nan', 'cos_sim': 0.9377005126033879}
# {'product_cat': 'Office Products', 'cos_sim': 0.9376061002176302}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9374721700897538}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9374623035078652}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9374031835454039}
# {'product_cat': 'Automotive', 'cos_sim': 0.937393047139481}
# {'product_cat': 'Office Products', 'cos_sim': 0.9372912152839552}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9372716794029553}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9372294035737256}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9370408827887116}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.937027546095766}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9368924867573036}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9368746227695445}
# {'product_cat': 'Office Products', 'cos_sim': 0.9368383560361527}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9367603088297868}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9366609607182829}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9366503520974887}
# {'product_cat': 'nan', 'cos_sim': 0.9365531029852431}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9365278901385053}
# {'product_cat': 'nan', 'cos_sim': 0.936387678504948}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9363702539565193}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9362619876901779}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9359477127831114}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9358302201456031}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9357285335565293}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9357200385833082}
# {'product_cat': 'Baby', 'cos_sim': 0.9356628603246588}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9356582292035479}
# {'product_cat': 'nan', 'cos_sim': 0.9356525347105432}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9355986630425119}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9355893875529988}
# {'product_cat': 'nan', 'cos_sim': 0.9355601843239585}
# {'product_cat': 'Baby', 'cos_sim': 0.9354630943152112}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9352427840746173}
# {'product_cat': 'Grocery & Gourmet Food', 'cos_sim': 0.9351158129989677}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.935103192464058}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9349898520695684}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9349062888619123}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9347412976879115}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9347262242132759}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9346864766906237}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9346682683831435}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9346015195195635}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9345738157147043}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9345521301676946}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9345126622194749}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9344055734227569}
# {'product_cat': 'Baby', 'cos_sim': 0.934326877107909}
# {'product_cat': 'Electronics', 'cos_sim': 0.9342176041798788}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9341846547939783}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9341783307437593}
# {'product_cat': 'Office Products', 'cos_sim': 0.9341437535079307}
# {'product_cat': 'Office Products', 'cos_sim': 0.9340754689270515}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9340139244407089}
# {'product_cat': 'Office Products', 'cos_sim': 0.9340103228364453}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9339740530029903}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9339250021295936}
# {'product_cat': 'Automotive', 'cos_sim': 0.9338657446390445}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9337204676349605}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9335861179104605}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9334822912560092}
# {'product_cat': 'nan', 'cos_sim': 0.9333478826460876}
# {'product_cat': 'Automotive', 'cos_sim': 0.9333278118903698}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9332733143684107}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9332508056387041}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9332118364579693}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9330468690041531}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9329605970122091}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.932927050308275}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9327498772387907}
# {'product_cat': 'Automotive', 'cos_sim': 0.932661898143612}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9326607246885997}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9325768436922616}
# {'product_cat': 'Automotive', 'cos_sim': 0.9324140789310178}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9323992448785455}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9323775570747186}
# {'product_cat': 'Baby', 'cos_sim': 0.9322339260058454}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9322090054853479}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9320276156988553}
# {'product_cat': 'Baby', 'cos_sim': 0.931959894779312}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9319526875741779}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9319025459597042}
# {'product_cat': 'Automotive', 'cos_sim': 0.9317894553316929}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.931758783891349}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.931730380299189}
# {'product_cat': 'Automotive', 'cos_sim': 0.9317091433482471}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9314570069379527}
# {'product_cat': 'Appliances', 'cos_sim': 0.9314173718787694}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9313354999961357}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9312871633849268}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9312011830890502}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9311274648597248}
# {'product_cat': 'Office Products', 'cos_sim': 0.9310668438715699}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9310314962894123}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9310274729127833}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9310060987710449}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9309923958606025}
# {'product_cat': 'Office Products', 'cos_sim': 0.9309173996948592}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9308710715096828}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9306934682848831}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9306861285570743}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.93067962604453}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9305534142766243}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9305529647913349}
# {'product_cat': 'Office Products', 'cos_sim': 0.9303771467197165}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9302584330450951}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.930187893719896}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9301408894206457}
# {'product_cat': 'Pet Supplies', 'cos_sim': 0.9300719982002724}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9300519211518551}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9300102091508315}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9298712534943654}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9298307192337348}
# {'product_cat': 'Pet Supplies', 'cos_sim': 0.9298204152670992}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9297453912851199}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9296818823597255}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9296014091377474}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9294812109209538}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9294646073870686}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9294394931655393}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9293679209794338}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.929179084490876}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9291017529821647}
# {'product_cat': 'Office Products', 'cos_sim': 0.9290850330518131}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9290010371704265}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9289736697790704}
# {'product_cat': 'Grocery & Gourmet Food', 'cos_sim': 0.9285891789685115}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9285769222363508}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9284766657084745}
# {'product_cat': 'Baby', 'cos_sim': 0.9284651861707391}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9284558356091228}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9283827162511712}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9282504199574599}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9282410665466553}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9280351026582017}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9280214812483457}
# {'product_cat': 'Baby', 'cos_sim': 0.928001372738723}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9279273045952917}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9276439039572962}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9275343008935159}
# {'product_cat': 'Baby', 'cos_sim': 0.927512967921116}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9273873367517268}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9273688971686321}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9273678002805763}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9273239222691473}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9271246871443262}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9270623631452991}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9270548288238405}
# {'product_cat': 'Office Products', 'cos_sim': 0.926901923237811}
# {'product_cat': 'Office Products', 'cos_sim': 0.9268737293370839}
# {'product_cat': 'nan', 'cos_sim': 0.9268366279174022}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9268361390636108}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9268167534749464}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9267385419001759}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9266809766292073}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9265943942999141}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9265489840999882}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9265453023282556}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9265081790898114}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9264500294699165}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9264136356128323}
# {'product_cat': 'Automotive', 'cos_sim': 0.9263802303224118}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9263417267929188}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9262590085781017}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9262379699292923}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9262218648598379}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9261701123254983}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': 0.9261571748092565}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9260565614320129}
# {'product_cat': 'Books', 'cos_sim': 0.926009239725276}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9259629135216201}
# {'product_cat': 'Baby', 'cos_sim': 0.9258791829307346}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9257650264449211}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9257306467704822}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9254789027274437}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9253849701293227}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.925374858501231}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.925099489939323}
# {'product_cat': 'Automotive', 'cos_sim': 0.9250894899275766}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.925051182143933}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9250441219497789}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9250434057230881}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.924979893735293}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9248903419610153}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.924810836232847}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9247443628535396}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9247415817494831}
# {'product_cat': 'Baby', 'cos_sim': 0.9246997429085689}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9246649627036114}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.924640072355982}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9246070786444394}
# {'product_cat': 'Automotive', 'cos_sim': 0.9245425820906238}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9245395270836423}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9244398180892535}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9243900776689332}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.924326344158374}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9242863332294144}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9242740955463007}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9241671635262853}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9240647737491924}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9240528784864597}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9239692365387585}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9239639930179598}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9237856554774302}
# {'product_cat': 'Automotive', 'cos_sim': 0.9237427228472818}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9236979176795812}
# {'product_cat': 'Grocery & Gourmet Food', 'cos_sim': 0.9236884193637114}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9236089063036448}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.923394345608621}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9233832012021536}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.923314189923468}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9232763465172542}
# {'product_cat': 'Baby Products', 'cos_sim': 0.9230155132910148}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9229786841205003}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.922857964915712}
# {'product_cat': 'Automotive', 'cos_sim': 0.9228368776691815}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9227531376060122}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9227389023246862}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9227116176119775}
# {'product_cat': 'nan', 'cos_sim': 0.9226535665923437}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': 0.9224733823816081}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9224451310433253}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9223800178018038}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9222991850855443}
# {'product_cat': 'Automotive', 'cos_sim': 0.9222852440847309}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9222763878310037}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9222762554817385}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9221205853610644}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9220510233361925}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9218586954942883}
# {'product_cat': 'Baby Products', 'cos_sim': 0.9217485245447672}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9217328041902054}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9215011974219512}
# {'product_cat': 'Pet Supplies', 'cos_sim': 0.9213740740537054}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9213149240691973}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9213103890385874}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9211413530487458}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9211117579974676}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9209346116812044}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9209163552895365}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9208613591017641}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9207284898783001}
# {'product_cat': 'Pet Supplies', 'cos_sim': 0.9206942649496859}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9206711839279568}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.920644104708965}
# {'product_cat': 'Pet Supplies', 'cos_sim': 0.9206058345290725}
# {'product_cat': 'Office Products', 'cos_sim': 0.9204376632747331}
# {'product_cat': 'Grocery & Gourmet Food', 'cos_sim': 0.9204024829050035}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': 0.9201934918306491}
# {'product_cat': 'Office Products', 'cos_sim': 0.9199935934167152}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9199479888367769}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9199391202563633}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9199156089282087}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9198668971600085}
# {'product_cat': 'Office Products', 'cos_sim': 0.9198200845807929}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9197091179868022}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9196553833250117}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9195907854573804}
# {'product_cat': 'Automotive', 'cos_sim': 0.9195741536965405}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9195127570848377}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9192388147755478}
# {'product_cat': 'Automotive', 'cos_sim': 0.9191008299156834}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9190570758288308}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9190201407096819}
# {'product_cat': 'Office Products', 'cos_sim': 0.918992023698018}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9188477224019747}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9188109339289784}
# {'product_cat': 'Automotive', 'cos_sim': 0.9187149455870528}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9186104301263277}
# {'product_cat': 'Appliances', 'cos_sim': 0.9185654602880099}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.9185064721824933}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9183750034056761}
# {'product_cat': 'Office Products', 'cos_sim': 0.9183583729041844}
# {'product_cat': 'Baby', 'cos_sim': 0.9182461949776645}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9181336732066766}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9178693108653916}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9178289013759142}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9177785809635772}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9177625041010344}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9177048912519334}
# {'product_cat': 'Automotive', 'cos_sim': 0.9176952090763054}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.9175189680540471}
# {'product_cat': 'Industrial & Scientific', 'cos_sim': 0.9174400280615193}
# {'product_cat': 'Automotive', 'cos_sim': 0.9173411719241545}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9172595950466215}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9172424681143817}
# {'product_cat': 'Pet Supplies', 'cos_sim': 0.9171602695146316}
# {'product_cat': 'Health & Personal Care', 'cos_sim': 0.917100289770783}
# {'product_cat': 'Patio, Lawn & Garden', 'cos_sim': 0.9170528867156235}
# {'product_cat': 'Automotive', 'cos_sim': 0.9170372628889257}
# {'product_cat': 'Grocery & Gourmet Food', 'cos_sim': 0.9168547816246813}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.9167159133599344}
# {'product_cat': 'Office Products', 'cos_sim': 0.9166687914687557}
# {'product_cat': 'Tools & Home Improvement', 'cos_sim': 0.9165156106903584}
# {'product_cat': 'nan', 'cos_sim': 0.9164975147337455}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': 0.9164746404693601}
# {'product_cat': 'Home & Kitchen', 'cos_sim': 0.9163940503909394}
# ...
# {'product_cat': 'Books', 'cos_sim': 0.6724086862294619}
# {'product_cat': 'Books', 'cos_sim': 0.6722440057373674}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6719737241195861}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6719416372904875}
# {'product_cat': 'Books', 'cos_sim': 0.6716836348467865}
# {'product_cat': 'Video Games', 'cos_sim': 0.671497525308463}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6712933724262089}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': 0.6712698573127509}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6705943587751476}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.670571406441569}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6701856668814065}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6698483206976522}
# {'product_cat': 'Books', 'cos_sim': 0.6698371881323254}
# {'product_cat': 'Books', 'cos_sim': 0.6697825018019913}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6697637251870049}
# {'product_cat': 'Electronics', 'cos_sim': 0.6696244935436175}
# {'product_cat': 'Books', 'cos_sim': 0.66948484839051}
# {'product_cat': 'Books', 'cos_sim': 0.6693244931835522}
# {'product_cat': 'Books', 'cos_sim': 0.6692921383439592}
# {'product_cat': 'Books', 'cos_sim': 0.6691921133897426}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6691164793635976}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.669023831355742}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6690216330078556}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6689052867579656}
# {'product_cat': 'Books', 'cos_sim': 0.6686602360300644}
# {'product_cat': 'Books', 'cos_sim': 0.6686447279372786}
# {'product_cat': 'Electronics', 'cos_sim': 0.6686332993334987}
# {'product_cat': 'Electronics', 'cos_sim': 0.6686203884340236}
# {'product_cat': 'Books', 'cos_sim': 0.6685576790077109}
# {'product_cat': 'Books', 'cos_sim': 0.6683705773012882}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6682909394078652}
# {'product_cat': 'Books', 'cos_sim': 0.6679011217023262}
# {'product_cat': 'Books', 'cos_sim': 0.667892941783287}
# {'product_cat': 'Books', 'cos_sim': 0.6678751405807435}
# {'product_cat': 'Electronics', 'cos_sim': 0.6678234784977689}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6675459769838658}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6670872238037804}
# {'product_cat': 'Kindle Store', 'cos_sim': 0.6670846526665688}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6670092809611035}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6668087749067444}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6666622354935271}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6665415114565436}
# {'product_cat': 'Books', 'cos_sim': 0.6663502738771094}
# {'product_cat': 'Video Games', 'cos_sim': 0.6660231368603984}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6653000769366969}
# {'product_cat': 'Books', 'cos_sim': 0.6648910974147689}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6644391017880822}
# {'product_cat': 'Books', 'cos_sim': 0.6640593241228309}
# {'product_cat': 'Beauty', 'cos_sim': 0.6637134572469824}
# {'product_cat': 'Books', 'cos_sim': 0.6630194514106207}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6629087513544414}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6628792968403121}
# {'product_cat': 'Books', 'cos_sim': 0.6628017727882928}
# {'product_cat': 'Electronics', 'cos_sim': 0.6627580329976395}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6621778646846752}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.662154457276685}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.661896395212462}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6618927388042131}
# {'product_cat': 'Electronics', 'cos_sim': 0.6616667998385365}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6616637891091318}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6614008138169624}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.661355212831202}
# {'product_cat': 'Electronics', 'cos_sim': 0.6612066403123885}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.661107051162632}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.661077072880742}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6609608778893139}
# {'product_cat': 'Books', 'cos_sim': 0.660855131256486}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6608484335605918}
# {'product_cat': 'Books', 'cos_sim': 0.6606560482515088}
# {'product_cat': 'Electronics', 'cos_sim': 0.6606184996263847}
# {'product_cat': 'Books', 'cos_sim': 0.6602653539082979}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6600053678057215}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.659957869399984}
# {'product_cat': 'Electronics', 'cos_sim': 0.6593924402567429}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6593447725531214}
# {'product_cat': 'Books', 'cos_sim': 0.6592216921828848}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6591213066228048}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.658700003430718}
# {'product_cat': 'Books', 'cos_sim': 0.6586158722530424}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6584569045861517}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6584428148772152}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6581130014668124}
# {'product_cat': 'Books', 'cos_sim': 0.6580628782254246}
# {'product_cat': 'Electronics', 'cos_sim': 0.6574448857455809}
# {'product_cat': 'Electronics', 'cos_sim': 0.6570726271159492}
# {'product_cat': 'Books', 'cos_sim': 0.6568870594229008}
# {'product_cat': 'Office Products', 'cos_sim': 0.6566380373695188}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.656542603093238}
# {'product_cat': 'Electronics', 'cos_sim': 0.656385929704881}
# {'product_cat': 'Electronics', 'cos_sim': 0.6563141007224143}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.656290167180701}
# {'product_cat': 'Books', 'cos_sim': 0.6560614035965312}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6560296486294491}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6560188628495754}
# {'product_cat': 'Video Games', 'cos_sim': 0.6558490481456003}
# {'product_cat': 'Electronics', 'cos_sim': 0.6555940036695727}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6537092483086453}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6535858094747826}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6533898115961893}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6532925724059755}
# {'product_cat': 'Books', 'cos_sim': 0.6529586335114155}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6528927818107864}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6524505290113529}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6524084410619034}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6518453245723663}
# {'product_cat': 'Video Games', 'cos_sim': 0.6517223868463828}
# {'product_cat': 'Video Games', 'cos_sim': 0.6510822227504426}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6505272213963574}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6503116028332576}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6495751301045749}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6493973124908645}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6493319740427467}
# {'product_cat': 'Electronics', 'cos_sim': 0.6492644661759698}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6485956654375149}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6480271291510052}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6479524083575571}
# {'product_cat': 'Beauty', 'cos_sim': 0.6468645921010071}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6467008052553634}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6463024231678401}
# {'product_cat': 'Software', 'cos_sim': 0.6462140656549191}
# {'product_cat': 'Luxury Beauty', 'cos_sim': 0.645467965902575}
# {'product_cat': 'Books', 'cos_sim': 0.6442402587477052}
# {'product_cat': 'Books', 'cos_sim': 0.6439074201663585}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6437684315496616}
# {'product_cat': 'Electronics', 'cos_sim': 0.6434591820556498}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6434393559986794}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6430678606817893}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6423405103843012}
# {'product_cat': 'Books', 'cos_sim': 0.641979839046525}
# {'product_cat': 'Books', 'cos_sim': 0.6415685429635093}
# {'product_cat': 'Toys & Games', 'cos_sim': 0.6410276075892042}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.640798776862084}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6397951380214577}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6397369031290027}
# {'product_cat': 'Electronics', 'cos_sim': 0.639705032555818}
# {'product_cat': 'Video Games', 'cos_sim': 0.6394120792198736}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6388143593583834}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6385628611359705}
# {'product_cat': 'Books', 'cos_sim': 0.6383217509481963}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6376210743058405}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6374813818681128}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6360446083270413}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.634954288783452}
# {'product_cat': 'Electronics', 'cos_sim': 0.633959653748529}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.633692538080643}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6332480219118277}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6332463832402865}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6327874544700698}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6313456965259981}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6312924354872798}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6308212880717998}
# {'product_cat': 'Electronics', 'cos_sim': 0.630657573637604}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.629482128977295}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6283604882663933}
# {'product_cat': 'Software', 'cos_sim': 0.6283281061836309}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6261716747320848}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6258442332629607}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6255487712227333}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6253162307211863}
# {'product_cat': 'Video Games', 'cos_sim': 0.6252187636368667}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6190151539057214}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6183521172420081}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6165235993627213}
# {'product_cat': 'Electronics', 'cos_sim': 0.6155696910126358}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6148002536308604}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.613391679907256}
# {'product_cat': 'Books', 'cos_sim': 0.6133719255474053}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.6119201114538291}
# {'product_cat': 'Books', 'cos_sim': 0.610745200176986}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6106653321267446}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6094543983085419}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6092262270670452}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6087113220037722}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6085516247641867}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.6066316833172714}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.6017808688556492}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.5999841905078985}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.5957179166171879}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.5932027385477465}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.5869920757659847}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.5862869515980045}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.5858020211712957}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.583001090377559}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': 0.5717513985123703}
# {'product_cat': 'Movies & TV', 'cos_sim': 0.5663806169651701}
# {'product_cat': 'Electronics', 'cos_sim': 0.5637964687952882}
# {'product_cat': 'Software', 'cos_sim': 0.5633123130219063}
# {'product_cat': 'Cell Phones & Accessories', 'cos_sim': 0.5621419686587787}
# {'product_cat': 'Electronics', 'cos_sim': 0.5231804683282384}
# {'product_cat': 'Video Games', 'cos_sim': 0.45869102799897615}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'nan', 'cos_sim': None}
# {'product_cat': 'Beauty', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': None}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Health & Personal Care', 'cos_sim': None}
# {'product_cat': 'Health & Personal Care', 'cos_sim': None}
# {'product_cat': 'Home & Kitchen', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Automotive', 'cos_sim': None}
# {'product_cat': 'Movies & TV', 'cos_sim': None}
# {'product_cat': 'Home & Kitchen', 'cos_sim': None}
# {'product_cat': 'Automotive', 'cos_sim': None}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Grocery & Gourmet Food', 'cos_sim': None}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Home & Kitchen', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Beauty', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Kindle Store', 'cos_sim': None}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Home & Kitchen', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Health & Personal Care', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Baby', 'cos_sim': None}
# {'product_cat': 'nan', 'cos_sim': None}
# {'product_cat': 'Beauty', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Arts, Crafts & Sewing', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Movies & TV', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': None}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'Beauty', 'cos_sim': None}
# {'product_cat': 'Beauty', 'cos_sim': None}
# {'product_cat': 'Clothing, Shoes & Jewelry', 'cos_sim': None}
# {'product_cat': 'Sports & Outdoors', 'cos_sim': None}
# {'product_cat': 'CDs & Vinyl', 'cos_sim': None}
# {'product_cat': 'Books', 'cos_sim': None}

# %% [markdown]
# Here we're using the cosine similarity to retrieve the product which can be bought together with a query product. The cosine similarity is calculated between the node embeddings of a query product and all the other 4999 products:
# $$
#  \frac{
#   \sum\limits_{i=1}^{n}{a_i b_i}
#   }{
#       \sqrt{\sum\limits_{j=1}^{n}{a_j^2}}
#       \sqrt{\sum\limits_{k=1}^{n}{b_k^2}}
#   }
# $$
#
#
#
# Once we calculate the cosine similarities, we can then SORT the products and return the highly likely bought together product with a query product!

# %% [markdown]
# ## Note:
# 1)For the demo purpose I am using 5000 test nodes but definitely if we go for more nodes results can be improved.
#
# 2) Also there is a lot of room for the improvement of the accuracy of model which can be achieved using hyperparameter tuning for e.g setting different number of search depths or playing with size of hidden layers like we have used 256 in our experiment. Another interesting thing to experiment would be using different neighborhood sampling techniques like random walk.
#
# Therefore, I can left this as a HomeWork for you !!
